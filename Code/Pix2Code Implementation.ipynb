# %%
import os
import hashlib
import shutil
import sys

import numpy as np
import cv2

IMAGE_SIZE = 256

platform_list = ["android", "ios","web"]
BASE_DIR = "/Users/abhjha8/kaggle_competitions/Image2Code/pix2code/datasets/{0}/all_data"
TRAINING_SET_NAME = "training_set"
EVALUATION_SET_NAME = "eval_set"
distribution = 6 # to decide the ratio of training and evaluation samples size


input_path_list = []

for platform in platform_list:
    input_path = BASE_DIR.format(platform)
    input_path_list.append(input_path)

# %% [markdown]
# # PREPARE THE DATASET

# %%
for input_path in input_path_list:
    paths = []

    for f in os.listdir(input_path):
        if f.find(".gui") != -1:
            path_gui = "{}/{}".format(input_path, f)
            file_name = f[:f.find(".gui")]

            if os.path.isfile("{}/{}.png".format(input_path, file_name)):
                path_img = "{}/{}.png".format(input_path, file_name)
                paths.append(file_name)

    evaluation_samples_number = len(paths) / (distribution + 1)
    training_samples_number = evaluation_samples_number * distribution

    assert training_samples_number + evaluation_samples_number == len(paths)

    print("Splitting datasets, training samples: {}, evaluation samples: {}".format(training_samples_number, evaluation_samples_number))

    np.random.shuffle(paths)

    eval_set = []
    train_set = []
    hashes = []
    for path in paths:
        with open("{}/{}.gui".format(input_path, path), 'r', encoding='utf-8') as f:
            chars = ""
            for line in f:
                chars += line
            content_hash = chars.replace(" ", "").replace("\n", "")
            content_hash = hashlib.sha256(content_hash.encode('utf-8')).hexdigest()

            if len(eval_set) == evaluation_samples_number:
                train_set.append(path)
            else:
                is_unique = True
                for h in hashes:
                    if h is content_hash:
                        is_unique = False
                        break

                if is_unique:
                    eval_set.append(path)
                else:
                    train_set.append(path)

            hashes.append(content_hash)

    assert len(eval_set) == evaluation_samples_number
    assert len(train_set) == training_samples_number

    if not os.path.exists("{}/{}".format(os.path.dirname(input_path), EVALUATION_SET_NAME)):
        os.makedirs("{}/{}".format(os.path.dirname(input_path), EVALUATION_SET_NAME))

    if not os.path.exists("{}/{}".format(os.path.dirname(input_path), TRAINING_SET_NAME)):
        os.makedirs("{}/{}".format(os.path.dirname(input_path), TRAINING_SET_NAME))

    for path in eval_set:
        shutil.copyfile("{}/{}.png".format(input_path, path), "{}/{}/{}.png".format(os.path.dirname(input_path), EVALUATION_SET_NAME, path))
        shutil.copyfile("{}/{}.gui".format(input_path, path), "{}/{}/{}.gui".format(os.path.dirname(input_path), EVALUATION_SET_NAME, path))

    for path in train_set:
        shutil.copyfile("{}/{}.png".format(input_path, path), "{}/{}/{}.png".format(os.path.dirname(input_path), TRAINING_SET_NAME, path))
        shutil.copyfile("{}/{}.gui".format(input_path, path), "{}/{}/{}.gui".format(os.path.dirname(input_path), TRAINING_SET_NAME, path))

    print("Training dataset: {}/training_set".format(os.path.dirname(input_path), path))
    print("Evaluation dataset: {}/eval_set".format(os.path.dirname(input_path), path))
# Out:
# Splitting datasets, training samples: 1500.0, evaluation samples: 250.0
# Training dataset: /Users/abhjha8/kaggle_competitions/Image2Code/pix2code/datasets/android/training_set
# Evaluation dataset: /Users/abhjha8/kaggle_competitions/Image2Code/pix2code/datasets/android/eval_set
# Splitting datasets, training samples: 1500.0, evaluation samples: 250.0
# Training dataset: /Users/abhjha8/kaggle_competitions/Image2Code/pix2code/datasets/ios/training_set
# Evaluation dataset: /Users/abhjha8/kaggle_competitions/Image2Code/pix2code/datasets/ios/eval_set
# Splitting datasets, training samples: 1500.0, evaluation samples: 250.0
# Training dataset: /Users/abhjha8/kaggle_competitions/Image2Code/pix2code/datasets/web/training_set
# Evaluation dataset: /Users/abhjha8/kaggle_competitions/Image2Code/pix2code/datasets/web/eval_set

# %%
def get_preprocessed_img(img_path, image_size):
    img = cv2.imread(img_path)
    img = cv2.resize(img, (image_size, image_size))
    img = img.astype('float32')
    img /= 255
    return img


TRAIN_IMAGE_DIR = "/Users/abhjha8/kaggle_competitions/Image2Code/pix2code/datasets/{0}/training_set"
TRAIN_FEATURES_DIR = "/Users/abhjha8/kaggle_competitions/Image2Code/pix2code/datasets/{0}/training_features"
input_path_list = []
output_path_mapping = dict()
for platform in platform_list:
    input_path = TRAIN_IMAGE_DIR.format(platform)
    output_path_mapping[input_path] = TRAIN_FEATURES_DIR.format(platform)
    if not os.path.exists(output_path_mapping[input_path]):
        os.makedirs(output_path_mapping[input_path])
    input_path_list.append(input_path)


print("Converting images to numpy arrays...")
for input_path in input_path_list:
    output_path = output_path_mapping[input_path]
    for f in os.listdir(input_path):
        if f.find(".png") != -1:
            img = get_preprocessed_img("{}/{}".format(input_path, f), IMAGE_SIZE)
            file_name = f[:f.find(".png")]

            np.savez_compressed("{}/{}".format(output_path, file_name), features=img)
            retrieve = np.load("{}/{}.npz".format(output_path, file_name))["features"]

            assert np.array_equal(img, retrieve)

            shutil.copyfile("{}/{}.gui".format(input_path, file_name), "{}/{}.gui".format(output_path, file_name))

    print("Numpy arrays saved in {}".format(output_path))
# Out:
# Converting images to numpy arrays...
# Numpy arrays saved in /Users/abhjha8/kaggle_competitions/Image2Code/pix2code/datasets/android/training_features
# Numpy arrays saved in /Users/abhjha8/kaggle_competitions/Image2Code/pix2code/datasets/ios/training_features
# Numpy arrays saved in /Users/abhjha8/kaggle_competitions/Image2Code/pix2code/datasets/web/training_features

# %% [markdown]
# # Training the data

# %%
from keras.models import model_from_json


class AModel:
    def __init__(self, input_shape, output_size, output_path):
        self.model = None
        self.input_shape = input_shape
        self.output_size = output_size
        self.output_path = output_path
        self.name = ""

    def save(self):
        model_json = self.model.to_json()
        with open("{}/{}.json".format(self.output_path, self.name), "w") as json_file:
            json_file.write(model_json)
        self.model.save_weights("{}/{}.h5".format(self.output_path, self.name))

    def load(self, name=""):
        output_name = self.name if name == "" else name
        with open("{}/{}.json".format(self.output_path, output_name), "r") as json_file:
            loaded_model_json = json_file.read()
        self.model = model_from_json(loaded_model_json)
        self.model.load_weights("{}/{}.h5".format(self.output_path, output_name))

# %%
from keras.layers import Input, Dense, Dropout, \
                         RepeatVector, LSTM, concatenate, \
                         Conv2D, MaxPooling2D, Flatten
from keras.models import Sequential, Model
# from keras.optimizers import RMSprop
from keras.optimizers.legacy import RMSprop
from keras import *

class pix2code(AModel):
    def __init__(self, input_shape, output_size, output_path):
        AModel.__init__(self, input_shape, output_size, output_path)
        self.name = "pix2code"

        image_model = Sequential()
        image_model.add(Conv2D(32, (3, 3), padding='valid', activation='relu', input_shape=input_shape))
        image_model.add(Conv2D(32, (3, 3), padding='valid', activation='relu'))
        image_model.add(MaxPooling2D(pool_size=(2, 2)))
        image_model.add(Dropout(0.25))

        image_model.add(Conv2D(64, (3, 3), padding='valid', activation='relu'))
        image_model.add(Conv2D(64, (3, 3), padding='valid', activation='relu'))
        image_model.add(MaxPooling2D(pool_size=(2, 2)))
        image_model.add(Dropout(0.25))

        image_model.add(Conv2D(128, (3, 3), padding='valid', activation='relu'))
        image_model.add(Conv2D(128, (3, 3), padding='valid', activation='relu'))
        image_model.add(MaxPooling2D(pool_size=(2, 2)))
        image_model.add(Dropout(0.25))

        image_model.add(Flatten())
        image_model.add(Dense(1024, activation='relu'))
        image_model.add(Dropout(0.3))
        image_model.add(Dense(1024, activation='relu'))
        image_model.add(Dropout(0.3))

        image_model.add(RepeatVector(CONTEXT_LENGTH))

        visual_input = Input(shape=input_shape)
        encoded_image = image_model(visual_input)

        language_model = Sequential()
        language_model.add(LSTM(128, return_sequences=True, input_shape=(CONTEXT_LENGTH, output_size)))
        language_model.add(LSTM(128, return_sequences=True))

        textual_input = Input(shape=(CONTEXT_LENGTH, output_size))
        encoded_text = language_model(textual_input)

        decoder = concatenate([encoded_image, encoded_text])

        decoder = LSTM(512, return_sequences=True)(decoder)
        decoder = LSTM(512, return_sequences=False)(decoder)
        decoder = Dense(output_size, activation='softmax')(decoder)

        self.model = Model(inputs=[visual_input, textual_input], outputs=decoder)

        optimizer = RMSprop(learning_rate=0.0001, clipvalue=1.0)
        self.model.compile(loss='categorical_crossentropy', optimizer=optimizer)

    def fit(self, images, partial_captions, next_words):
        self.model.fit([images, partial_captions], next_words, shuffle=False, epochs=EPOCHS, batch_size=BATCH_SIZE, verbose=1)
        self.save()

    def fit_generator(self, generator, steps_per_epoch):
        self.model.fit(generator, steps_per_epoch=steps_per_epoch, epochs=EPOCHS, verbose=1)
        self.save()

    def predict(self, image, partial_caption):
        return self.model.predict([image, partial_caption], verbose=0)[0]

    def predict_batch(self, images, partial_captions):
        return self.model.predict([images, partial_captions], verbose=1)

# %%
CONTEXT_LENGTH = 48
IMAGE_SIZE = 256
BATCH_SIZE = 64
EPOCHS = 10
STEPS_PER_EPOCH = 72000


START_TOKEN = "<START>"
END_TOKEN = "<END>"
PLACEHOLDER = " "
SEPARATOR = '->'


class Vocabulary:
    def __init__(self):
        self.binary_vocabulary = {}
        self.vocabulary = {}
        self.token_lookup = {}
        self.size = 0

        self.append(START_TOKEN)
        self.append(END_TOKEN)
        self.append(PLACEHOLDER)

    def append(self, token):
        if token not in self.vocabulary:
            self.vocabulary[token] = self.size
            self.token_lookup[self.size] = token
            self.size += 1

    def create_binary_representation(self):
        if sys.version_info >= (3,):
            items = self.vocabulary.items()
        else:
            items = self.vocabulary.iteritems()
        for key, value in items:
            binary = np.zeros(self.size)
            binary[value] = 1
            self.binary_vocabulary[key] = binary

    def get_serialized_binary_representation(self):
        if len(self.binary_vocabulary) == 0:
            self.create_binary_representation()

        string = ""
        if sys.version_info >= (3,):
            items = self.binary_vocabulary.items()
        else:
            items = self.binary_vocabulary.iteritems()
        for key, value in items:
            array_as_string = np.array2string(value, separator=',', max_line_width=self.size * self.size)
            string += "{}{}{}\n".format(key, SEPARATOR, array_as_string[1:len(array_as_string) - 1])
        return string

    def save(self, path):
        output_file_name = "{}/words.vocab".format(path)
        output_file = open(output_file_name, 'w')
        output_file.write(self.get_serialized_binary_representation())
        output_file.close()

    def retrieve(self, path):
        input_file = open("{}/words.vocab".format(path), 'r')
        buffer = ""
        for line in input_file:
            try:
                separator_position = len(buffer) + line.index(SEPARATOR)
                buffer += line
                key = buffer[:separator_position]
                value = buffer[separator_position + len(SEPARATOR):]
                value = np.fromstring(value, sep=',')

                self.binary_vocabulary[key] = value
                self.vocabulary[key] = np.where(value == 1)[0][0]
                self.token_lookup[np.where(value == 1)[0][0]] = key

                buffer = ""
            except ValueError:
                buffer += line
        input_file.close()
        self.size = len(self.vocabulary)

# %%
class Utils:
    @staticmethod
    def sparsify(label_vector, output_size):
        sparse_vector = []

        for label in label_vector:
            sparse_label = np.zeros(output_size)
            sparse_label[label] = 1

            sparse_vector.append(sparse_label)

        return np.array(sparse_vector)

    @staticmethod
    def get_preprocessed_img(img_path, image_size):
        import cv2
        img = cv2.imread(img_path)
        img = cv2.resize(img, (image_size, image_size))
        img = img.astype('float32')
        img /= 255
        return img

    @staticmethod
    def show(image):
        import cv2
        cv2.namedWindow("view", cv2.WINDOW_AUTOSIZE)
        cv2.imshow("view", image)
        cv2.waitKey(0)
        cv2.destroyWindow("view")

# %%
class Dataset:
    def __init__(self):
        self.input_shape = None
        self.output_size = None

        self.ids = []
        self.input_images = []
        self.partial_sequences = []
        self.next_words = []

        self.voc = Vocabulary()
        self.size = 0

    @staticmethod
    def load_paths_only(path):
        print("Parsing data...")
        gui_paths = []
        img_paths = []
        for f in os.listdir(path):
            if f.find(".gui") != -1:
                path_gui = "{}/{}".format(path, f)
                gui_paths.append(path_gui)
                file_name = f[:f.find(".gui")]

                if os.path.isfile("{}/{}.png".format(path, file_name)):
                    path_img = "{}/{}.png".format(path, file_name)
                    img_paths.append(path_img)
                elif os.path.isfile("{}/{}.npz".format(path, file_name)):
                    path_img = "{}/{}.npz".format(path, file_name)
                    img_paths.append(path_img)

        assert len(gui_paths) == len(img_paths)
        return gui_paths, img_paths

    def load(self, path, generate_binary_sequences=False):
        print("Loading data...")
        for f in os.listdir(path):
            if f.find(".gui") != -1:
                gui = open("{}/{}".format(path, f), 'r')
                file_name = f[:f.find(".gui")]

                if os.path.isfile("{}/{}.png".format(path, file_name)):
                    img = Utils.get_preprocessed_img("{}/{}.png".format(path, file_name), IMAGE_SIZE)
                    self.append(file_name, gui, img)
                elif os.path.isfile("{}/{}.npz".format(path, file_name)):
                    img = np.load("{}/{}.npz".format(path, file_name))["features"]
                    self.append(file_name, gui, img)

        print("Generating sparse vectors...")
        self.voc.create_binary_representation()
        self.next_words = self.sparsify_labels(self.next_words, self.voc)
        if generate_binary_sequences:
            self.partial_sequences = self.binarize(self.partial_sequences, self.voc)
        else:
            self.partial_sequences = self.indexify(self.partial_sequences, self.voc)

        self.size = len(self.ids)
        assert self.size == len(self.input_images) == len(self.partial_sequences) == len(self.next_words)
        assert self.voc.size == len(self.voc.vocabulary)

        print("Dataset size: {}".format(self.size))
        print("Vocabulary size: {}".format(self.voc.size))

        self.input_shape = self.input_images[0].shape
        self.output_size = self.voc.size

        print("Input shape: {}".format(self.input_shape))
        print("Output size: {}".format(self.output_size))

    def convert_arrays(self):
        print("Convert arrays...")
        self.input_images = np.array(self.input_images)
        self.partial_sequences = np.array(self.partial_sequences)
        self.next_words = np.array(self.next_words)

    def append(self, sample_id, gui, img, to_show=False):
        if to_show:
            pic = img * 255
            pic = np.array(pic, dtype=np.uint8)
            Utils.show(pic)

        token_sequence = [START_TOKEN]
        for line in gui:
            line = line.replace(",", " ,").replace("\n", " \n")
            tokens = line.split(" ")
            for token in tokens:
                self.voc.append(token)
                token_sequence.append(token)
        token_sequence.append(END_TOKEN)

        suffix = [PLACEHOLDER] * CONTEXT_LENGTH

        a = np.concatenate([suffix, token_sequence])
        for j in range(0, len(a) - CONTEXT_LENGTH):
            context = a[j:j + CONTEXT_LENGTH]
            label = a[j + CONTEXT_LENGTH]

            self.ids.append(sample_id)
            self.input_images.append(img)
            self.partial_sequences.append(context)
            self.next_words.append(label)

    @staticmethod
    def indexify(partial_sequences, voc):
        temp = []
        for sequence in partial_sequences:
            sparse_vectors_sequence = []
            for token in sequence:
                sparse_vectors_sequence.append(voc.vocabulary[token])
            temp.append(np.array(sparse_vectors_sequence))

        return temp

    @staticmethod
    def binarize(partial_sequences, voc):
        temp = []
        for sequence in partial_sequences:
            sparse_vectors_sequence = []
            for token in sequence:
                sparse_vectors_sequence.append(voc.binary_vocabulary[token])
            temp.append(np.array(sparse_vectors_sequence))

        return temp

    @staticmethod
    def sparsify_labels(next_words, voc):
        temp = []
        for label in next_words:
            temp.append(voc.binary_vocabulary[label])

        return temp

    def save_metadata(self, path):
        metadata_array = np.array([self.input_shape, self.output_size, self.size], dtype=object)
        np.save("{}/meta_dataset".format(path), metadata_array)

# %%
class Generator:
    @staticmethod
    def data_generator(voc, gui_paths, img_paths, batch_size, generate_binary_sequences=False, verbose=False, loop_only_one=False):
        assert len(gui_paths) == len(img_paths)
        voc.create_binary_representation()

        while 1:
            batch_input_images = []
            batch_partial_sequences = []
            batch_next_words = []
            sample_in_batch_counter = 0

            for i in range(0, len(gui_paths)):
                if img_paths[i].find(".png") != -1:
                    img = Utils.get_preprocessed_img(img_paths[i], IMAGE_SIZE)
                else:
                    img = np.load(img_paths[i])["features"]
                gui = open(gui_paths[i], 'r')

                token_sequence = [START_TOKEN]
                for line in gui:
                    line = line.replace(",", " ,").replace("\n", " \n")
                    tokens = line.split(" ")
                    for token in tokens:
                        voc.append(token)
                        token_sequence.append(token)
                token_sequence.append(END_TOKEN)

                suffix = [PLACEHOLDER] * CONTEXT_LENGTH

                a = np.concatenate([suffix, token_sequence])
                for j in range(0, len(a) - CONTEXT_LENGTH):
                    context = a[j:j + CONTEXT_LENGTH]
                    label = a[j + CONTEXT_LENGTH]

                    batch_input_images.append(img)
                    batch_partial_sequences.append(context)
                    batch_next_words.append(label)
                    sample_in_batch_counter += 1

                    if sample_in_batch_counter == batch_size or (loop_only_one and i == len(gui_paths) - 1):
                        if verbose:
                            print("Generating sparse vectors...")
                        batch_next_words = Dataset.sparsify_labels(batch_next_words, voc)
                        if generate_binary_sequences:
                            batch_partial_sequences = Dataset.binarize(batch_partial_sequences, voc)
                        else:
                            batch_partial_sequences = Dataset.indexify(batch_partial_sequences, voc)

                        if verbose:
                            print("Convert arrays...")
                        batch_input_images = np.array(batch_input_images)
                        batch_partial_sequences = np.array(batch_partial_sequences)
                        batch_next_words = np.array(batch_next_words)

                        if verbose:
                            print("Yield batch")
                        yield ([batch_input_images, batch_partial_sequences], batch_next_words)

                        batch_input_images = []
                        batch_partial_sequences = []
                        batch_next_words = []
                        sample_in_batch_counter = 0

# %%
# random_seed_val = 1234
# def run(input_path, output_path, is_memory_intensive=True, pretrained_model=None):

#     dataset = Dataset()
#     dataset.load(input_path, generate_binary_sequences=True)
#     dataset.save_metadata(output_path)
#     dataset.voc.save(output_path)

#     if not is_memory_intensive:
#         dataset.convert_arrays()

#         input_shape = dataset.input_shape
#         output_size = dataset.output_size

#         print(len(dataset.input_images), len(dataset.partial_sequences), len(dataset.next_words))
#         print(dataset.input_images.shape, dataset.partial_sequences.shape, dataset.next_words.shape)
#     else:
#         gui_paths, img_paths = Dataset.load_paths_only(input_path)

#         input_shape = dataset.input_shape
#         output_size = dataset.output_size
#         steps_per_epoch = dataset.size / BATCH_SIZE

#         voc = Vocabulary()
#         voc.retrieve(output_path)

#         generator = Generator.data_generator(voc, gui_paths, img_paths, batch_size=BATCH_SIZE, generate_binary_sequences=True)

#     model = pix2code(input_shape, output_size, output_path)

#     if pretrained_model is not None:
#         model.model.load_weights(pretrained_model)

#     if not is_memory_intensive:
#         model.fit(dataset.input_images, dataset.partial_sequences, dataset.next_words)
#     else:
#         model.fit_generator(generator, steps_per_epoch=steps_per_epoch)

# if __name__ == "__main__":
#     np.random.seed(random_seed_val)
#     input_path = "/Users/abhjha8/kaggle_competitions/Image2Code/pix2code/datasets/ios/training_set"
#     output_path = "/Users/abhjha8/kaggle_competitions/Image2Code/pix2code/model_ios"
#     use_generator = True
#     pretrained_weigths = None
#     run(input_path, output_path, is_memory_intensive=use_generator, pretrained_model=pretrained_weigths)

# %% [markdown]
# # Generating the Results

# %%
class Node:
    def __init__(self, key, value, data=None):
        self.key = key
        self.value = value
        self.data = data
        self.parent = None
        self.root = None
        self.children = []
        self.level = 0

    def add_children(self, children, beam_width):
        for child in children:
            child.level = self.level + 1
            child.value = child.value * self.value

        nodes = sorted(children, key=lambda node: node.value, reverse=True)
        nodes = nodes[:beam_width]

        for node in nodes:
            self.children.append(node)
            node.parent = self

        if self.parent is None:
            self.root = self
        else:
            self.root = self.parent.root
        child.root = self.root

    def remove_child(self, child):
        self.children.remove(child)

    def max_child(self):
        if len(self.children) == 0:
            return self

        max_childs = []
        for child in self.children:
            max_childs.append(child.max_child())

        nodes = sorted(max_childs, key=lambda child: child.value, reverse=True)
        return nodes[0]

    def show(self, depth=0):
        print(" " * depth, self.key, self.value, self.level)
        for child in self.children:
            child.show(depth + 2)


class BeamSearch:
    def __init__(self, beam_width=1):
        self.beam_width = beam_width

        self.root = None
        self.clear()

    def search(self):
        result = self.root.max_child()

        self.clear()
        return self.retrieve_path(result)

    def add_nodes(self, parent, children):
        parent.add_children(children, self.beam_width)

    def is_valid(self):
        leaves = self.get_leaves()
        level = leaves[0].level
        counter = 0
        for leaf in leaves:
            if leaf.level == level:
                counter += 1
            else:
                break

        if counter == len(leaves):
            return True

        return False

    def get_leaves(self):
        leaves = []
        self.search_leaves(self.root, leaves)
        return leaves

    def search_leaves(self, node, leaves):
        for child in node.children:
            if len(child.children) == 0:
                leaves.append(child)
            else:
                self.search_leaves(child, leaves)

    def prune_leaves(self):
        leaves = self.get_leaves()

        nodes = sorted(leaves, key=lambda leaf: leaf.value, reverse=True)
        nodes = nodes[self.beam_width:]

        for node in nodes:
            node.parent.remove_child(node)

        while not self.is_valid():
            leaves = self.get_leaves()
            max_level = 0
            for leaf in leaves:
                if leaf.level > max_level:
                    max_level = leaf.level

            for leaf in leaves:
                if leaf.level < max_level:
                    leaf.parent.remove_child(leaf)

    def clear(self):
        self.root = None
        self.root = Node("root", 1.0, None)

    def retrieve_path(self, end):
        path = [end.key]
        data = [end.data]
        while end.parent is not None:
            end = end.parent
            path.append(end.key)
            data.append(end.data)

        result_path = []
        result_data = []
        for i in range(len(path) - 2, -1, -1):
            result_path.append(path[i])
            result_data.append(data[i])
        return result_path, result_data

# %%
class Sampler:
    def __init__(self, voc_path, input_shape, output_size, context_length):
        self.voc = Vocabulary()
        self.voc.retrieve(voc_path)

        self.input_shape = input_shape
        self.output_size = output_size

        print("Vocabulary size: {}".format(self.voc.size))
        print("Input shape: {}".format(self.input_shape))
        print("Output size: {}".format(self.output_size))

        self.context_length = context_length

    def predict_greedy(self, model, input_img, require_sparse_label=True, sequence_length=150, verbose=False):
        current_context = [self.voc.vocabulary[PLACEHOLDER]] * (self.context_length - 1)
        current_context.append(self.voc.vocabulary[START_TOKEN])
        if require_sparse_label:
            current_context = Utils.sparsify(current_context, self.output_size)

        predictions = START_TOKEN
        out_probas = []

        for i in range(0, sequence_length):
            if verbose:
                print("predicting {}/{}...".format(i, sequence_length))

            probas = model.predict(input_img, np.array([current_context]))
            prediction = np.argmax(probas)
            out_probas.append(probas)

            new_context = []
            for j in range(1, self.context_length):
                new_context.append(current_context[j])

            if require_sparse_label:
                sparse_label = np.zeros(self.output_size)
                sparse_label[prediction] = 1
                new_context.append(sparse_label)
            else:
                new_context.append(prediction)

            current_context = new_context

            predictions += self.voc.token_lookup[prediction]

            if self.voc.token_lookup[prediction] == END_TOKEN:
                break

        return predictions, out_probas

    def recursive_beam_search(self, model, input_img, current_context, beam, current_node, sequence_length):
        probas = model.predict(input_img, np.array([current_context]))

        predictions = []
        for i in range(0, len(probas)):
            predictions.append((i, probas[i], probas))

        nodes = []
        for i in range(0, len(predictions)):
            prediction = predictions[i][0]
            score = predictions[i][1]
            output_probas = predictions[i][2]
            nodes.append(Node(prediction, score, output_probas))

        beam.add_nodes(current_node, nodes)

        if beam.is_valid():
            beam.prune_leaves()
            if sequence_length == 1 or self.voc.token_lookup[beam.root.max_child().key] == END_TOKEN:
                return

            for node in beam.get_leaves():
                prediction = node.key

                new_context = []
                for j in range(1, self.context_length):
                    new_context.append(current_context[j])
                sparse_label = np.zeros(self.output_size)
                sparse_label[prediction] = 1
                new_context.append(sparse_label)

                self.recursive_beam_search(model, input_img, new_context, beam, node, sequence_length - 1)

    def predict_beam_search(self, model, input_img, beam_width=3, require_sparse_label=True, sequence_length=150):
        predictions = START_TOKEN
        out_probas = []

        current_context = [self.voc.vocabulary[PLACEHOLDER]] * (self.context_length - 1)
        current_context.append(self.voc.vocabulary[START_TOKEN])
        if require_sparse_label:
            current_context = Utils.sparsify(current_context, self.output_size)

        beam = BeamSearch(beam_width=beam_width)

        self.recursive_beam_search(model, input_img, current_context, beam, beam.root, sequence_length)

        predicted_sequence, probas_sequence = beam.search()

        for k in range(0, len(predicted_sequence)):
            prediction = predicted_sequence[k]
            probas = probas_sequence[k]
            out_probas.append(probas)

            predictions += self.voc.token_lookup[prediction]

        return predictions, out_probas

# %%
# import os
# from classes.Sampler import *
# from classes.model.pix2code import *

# To generate gui files

model_web = "/Users/abhjha8/kaggle_competitions/Image2Code/pix2code/model_web"
model_android = "/Users/abhjha8/kaggle_competitions/Image2Code/pix2code/model_android"
model_ios = "/Users/abhjha8/kaggle_competitions/Image2Code/pix2code/model_ios"

trained_weights_path = "/Users/abhjha8/kaggle_competitions/Image2Code/pix2code/model_android"
trained_model_name = "pix2code"
input_path = "/Users/abhjha8/kaggle_competitions/Image2Code/pix2code/datasets/web/eval_set"
output_path = "/Users/abhjha8/kaggle_competitions/Image2Code/pix2code/datasets/web/model_result_gui"
search_method = "greedy"

if not os.path.exists(output_path):
    os.makedirs(output_path)

meta_dataset = np.load("{}/meta_dataset.npy".format(trained_weights_path), allow_pickle=True)

input_shape = meta_dataset[0]
output_size = meta_dataset[1]

model = pix2code(input_shape, output_size, trained_weights_path)
model.load(trained_model_name)

sampler = Sampler(trained_weights_path, input_shape, output_size, CONTEXT_LENGTH)

for f in os.listdir(input_path):
    if f.find(".png") != -1:
        print("Generating Code for '{}'".format(f))
        evaluation_img = Utils.get_preprocessed_img("{}/{}".format(input_path, f), IMAGE_SIZE)

        file_name = f[:f.find(".png")]

        if search_method == "greedy":
            result, _ = sampler.predict_greedy(model, np.array([evaluation_img]))
            # print("Result greedy: {}".format(result))
        else:
            beam_width = int(search_method)
            # print("Search with beam width: {}".format(beam_width))
            result, _ = sampler.predict_beam_search(model, np.array([evaluation_img]), beam_width=beam_width)
            # print("Result beam: {}".format(result))

        with open("{}/{}.gui".format(output_path, file_name), 'w') as out_f:
            out_f.write(result.replace(START_TOKEN, "").replace(END_TOKEN, ""))
# Out:
# Vocabulary size: 20
# Input shape: (256, 256, 3)
# Output size: 20
# Generating Code for '55C83592-BF31-44AF-8006-844F1C5CBCB9.png'
# Generating Code for '6F6151F8-FB4C-47C9-8FD2-532A19F45971.png'
# Generating Code for '2BE940B3-F4A4-428F-86C8-10CB885CD62E.png'
# Generating Code for '80E84FD8-3A24-419E-9CEC-D1E46E6179B4.png'
# Generating Code for 'AB660EA5-9546-4BD9-B2C6-00E53CBC2AE6.png'
# Generating Code for '891C8311-6939-4665-B139-09AC75D0AAA4.png'
# Generating Code for '297E5EC4-4A0D-4B9E-837F-E5B9B1F84083.png'
# Generating Code for '3C2FA230-DD5A-4182-8559-BD3F71943264.png'
# Generating Code for 'BEEBDE65-36F8-4628-A0DC-9DBE23E34D73.png'
# Generating Code for '3CFAE645-5CD0-48F2-98C3-6DDBAA392C89.png'
# Generating Code for 'FDBD8D36-B4F0-4398-9881-9B4EDE94BED1.png'
# Generating Code for 'DB1A585C-D4C9-4362-AA4E-13CBE7B37067.png'
# Generating Code for '65464850-0777-4513-9780-BC48F590FD2D.png'
# Generating Code for '8443A6BB-E5B9-43C3-99A5-E60AEFBC433A.png'
# Generating Code for '30EEFC5A-7BAC-43BC-9DD0-F47A32F42195.png'
# Generating Code for 'DAD5CEFA-37CA-48C8-8BC7-ECC5615077D9.png'
# Generating Code for '8C800285-4966-41CC-BBC2-826DF1F35D87.png'
# Generating Code for '097BCAB5-B471-48F7-A32A-591A9AA3EF75.png'
# Generating Code for '5DE4CCA5-3DC2-4208-B8B5-9C434D450DF6.png'
# Generating Code for 'BDA036F7-DDAE-4AEC-8453-C6216F6447E3.png'
# Generating Code for 'AD88100E-6FDB-404B-80FA-402C7366941A.png'
# Generating Code for '38E1F466-4615-4D4E-9BFF-6D09CA5BDF90.png'
# Generating Code for 'F916A3DF-CDF3-4CD1-B188-20DEC1D261FC.png'
# Generating Code for '51D1C4DD-75C7-4A8F-A886-8CFD832B4423.png'
# Generating Code for 'B8BB669D-18E5-4371-83B6-FB2293CF6D14.png'
# Generating Code for '5A02B078-D35C-4911-B498-235DC827137F.png'
# Generating Code for 'D3B9CCEF-2D17-447A-93DF-15F3AC929106.png'
# Generating Code for 'B471F4EB-89C4-46AC-AC8D-CB789AF37BC4.png'
# Generating Code for 'AAD1DAFF-132E-436E-AF8A-1EE476B22345.png'
# Generating Code for 'F79FFC31-1C16-4E8D-8C20-5DC92D8BB743.png'
# Generating Code for '3B9F555A-5CA3-4245-8AF0-6DC658DA4886.png'
# Generating Code for '747C2F4E-A98D-4AD9-941D-24ADB7F35ECB.png'
# Generating Code for '56D938B4-C281-42BD-BE09-C9D887697DE3.png'
# Generating Code for 'E2F5D9F1-159D-4641-9AC5-0C4E6EE73082.png'
# Generating Code for 'FACAF899-A6A5-4218-9AB9-9860CA4C5B12.png'
# Generating Code for '68F14192-3771-478D-AE21-0656DB902DFD.png'
# Generating Code for '1EFAB8BE-3A26-4499-8F73-0AC06A3F4305.png'
# Generating Code for 'D40F2B4A-B7B9-4B24-90E0-EF521725AB8C.png'
# Generating Code for '1EACABD4-EF65-46D0-82D3-F01EDCCA4992.png'
# Generating Code for '0E3A4C67-C470-41F0-902D-3EB3B92E883E.png'
# Generating Code for '8ACEAAF8-38CC-4C49-911C-DB74BA8A3B07.png'
# Generating Code for '3C593055-8F7B-4270-BD2C-ADEEAF03135F.png'
# Generating Code for '389EFD08-5454-4B00-9B49-9F34802909C7.png'
# Generating Code for '816D827D-2D0B-4A9A-B3B8-70220B207340.png'
# Generating Code for '2BC033FD-F097-463B-98A8-C1C9CE50B478.png'
# Generating Code for 'F45323B1-EAA1-4971-B430-6265C249752B.png'
# Generating Code for 'BEEBE977-4B0E-4C64-8D65-0187A21306F6.png'
# Generating Code for '7DC5C1A5-86C7-445C-A0FE-C30A019DA612.png'
# Generating Code for '1E28DC64-1819-4DAD-BFAD-3247FBF073B9.png'
# Generating Code for '24E540D8-9D42-46B6-8FD9-BB4442A3C9E8.png'
# Generating Code for '07B89ADE-2FBD-4713-A7F4-C394E28D0AF5.png'
# Generating Code for '1A1F0968-0AC1-46F9-BEC4-08DDD1250F4E.png'
# Generating Code for 'F8844C2F-CF0B-481B-97D7-38D729FD651D.png'
# Generating Code for '33071C62-88D7-46CF-A50C-9763D3163711.png'
# Generating Code for '809CC940-9232-4F4E-88E5-3A3991F1D678.png'
# Generating Code for 'A6960AA5-56D4-4A51-9B8C-C7B06B6BAECF.png'
# Generating Code for 'B0DF702B-36C4-4162-93C9-51115EF256D3.png'
# Generating Code for 'F586BD0C-E9DD-488E-AFB5-3512535B3E4D.png'
# Generating Code for 'FC64274A-D8FD-4151-A228-F73FFB6541F9.png'
# Generating Code for '66674423-FB28-4B44-AF47-58DE87303467.png'
# Generating Code for '99C6712C-0346-4A5C-BADB-1C7E820F18D7.png'
# Generating Code for '5E15E0FC-21AF-42EE-9CBC-3E6E30C662A6.png'
# Generating Code for '042B145D-1E0D-47CB-B16C-7F49B64DFF53.png'
# Generating Code for '15A67515-D740-4388-AFC7-A7279F84DB76.png'
# Generating Code for '5404130F-7754-40A8-AF07-82CA2E6CE151.png'
# Generating Code for '7DFF0C40-3DDA-4DC1-A8AA-47D6277F8064.png'
# Generating Code for '856823BB-3D57-4A63-A896-C7F6FEABDF0A.png'
# Generating Code for '501B6A70-83C9-46FD-B48D-D3AB6908B1FB.png'
# Generating Code for '276971FE-95B1-44BB-9E55-E30E03447512.png'
# Generating Code for 'AD57BFD8-D65E-4E63-AC53-F4D5C00962ED.png'
# Generating Code for '882C4A08-385B-4255-9DBE-7DA407A2F2C7.png'
# Generating Code for '3B3E1C56-A7AA-408B-B933-100E78D9339E.png'
# Generating Code for '669D5C57-3D03-41EF-82A7-F1B829218CD4.png'
# Generating Code for 'C9B34CD3-59D9-42E8-9F1F-F4CB698B5C29.png'
# Generating Code for 'C6F1A3E4-FBC2-4371-AED5-2F1CF04C8E13.png'
# Generating Code for '33960BCB-6313-4EF3-B521-A87E59A22536.png'
# Generating Code for 'EDB151F3-AF0D-4DFF-8117-5E5C69F08616.png'
# Generating Code for '9E743123-BC0C-4EE8-81E0-D414A417A31C.png'
# Generating Code for '8E00D88A-D1D2-44C3-BEB3-5825440C90F9.png'
# Generating Code for '8E1BE7E1-5C10-4B9F-AB53-AEA1BD04D3FB.png'
# Generating Code for '9D55B368-417A-48FD-B161-758784C96EB6.png'
# Generating Code for 'BD1AFF98-1419-4863-B76D-CC0FFABEF16E.png'
# Generating Code for '3AD39243-A1A7-472E-BB8B-A6ABA5730CA5.png'
# Generating Code for '9D7243C0-9A5C-428E-9BB5-9300D02455C7.png'
# Generating Code for 'D873BD58-A2F0-4E7A-AE66-3DA42E653D31.png'
# Generating Code for '7C7D53B9-CEDB-4338-8486-08F09FE912B6.png'
# Generating Code for '7D5A2194-9EE5-4889-B979-5966B886EAB1.png'
# Generating Code for '9A531675-660F-475D-833E-2FF07A41D0C8.png'
# Generating Code for '9C6E0543-9D7C-4907-A8A1-EDE9018B1DA1.png'
# Generating Code for '83F99F16-265A-4507-AE02-6B93CCE62A32.png'
# Generating Code for '8EC58508-E45F-4BD2-AF85-318F70D64FD8.png'
# Generating Code for 'B017D3FD-567E-4EF5-BC4B-FEB095FF07AE.png'
# Generating Code for '5C375DD1-AF13-41F1-B962-248927157CFE.png'
# Generating Code for 'A184C909-D2FE-49FD-B0AC-ECC02053F1E1.png'
# Generating Code for 'E8BEB0A0-599F-4FBE-B85A-8A2F6406605B.png'
# Generating Code for '7D9995CC-74DB-4725-9871-6FAC2410242E.png'
# Generating Code for '8818AF0F-37B2-496E-BFC8-4D95FE024598.png'
# Generating Code for '54BBB984-B3E7-40CC-8008-D93F35D7B04A.png'
# Generating Code for '90CBD93C-643D-4235-911A-CF280BFB0DF6.png'
# Generating Code for '8E6A58C9-7AE4-4666-9812-83E412899367.png'
# Generating Code for 'CFC445E0-118B-416A-8AAE-6D91ADD4394F.png'
# Generating Code for 'E75CC0CE-8C71-49BA-9A3D-AEF231C7A561.png'
# Generating Code for 'A7BFE52B-25C7-4A61-BFAC-57AF7A6E3BBC.png'
# Generating Code for '6952EB62-2CF3-4BF7-9099-FCBBF92D1152.png'
# Generating Code for '89E58377-5F3C-440D-A97E-08C05A3D039B.png'
# Generating Code for '624A5F5F-8D62-46B1-A0FA-CAF407EFCE0D.png'
# Generating Code for 'A7BFA607-C139-4300-B64C-CC7B5F770B3E.png'
# Generating Code for '1509D55B-0536-4766-9440-C25E4CA8E3FD.png'
# Generating Code for 'FD1D6CE9-C7AE-43C7-8132-4859237203DF.png'
# Generating Code for '9C21B3AC-89D7-4A90-95F8-001286AF9791.png'
# Generating Code for '97EEA143-758D-48A3-953E-E8A42343A7DD.png'
# Generating Code for 'A709C5FD-434B-4505-B88F-057DE569A68F.png'
# Generating Code for '559E7FA0-E9C3-45AB-88E5-31BB1C27B543.png'
# Generating Code for 'A512F0C0-00F0-4CFE-818C-D589A5870B09.png'
# Generating Code for '909445A3-34E3-4FC6-A756-4D4D263D71CD.png'
# Generating Code for '98D056DE-3846-406F-8D48-71564A4A1CCF.png'
# Generating Code for '7F80CE37-09ED-42FC-9EA1-73C6872A53CF.png'
# Generating Code for 'DBDBA4D5-6823-4E6B-B14C-DCADC3F3675E.png'
# Generating Code for 'C0DA91A9-A233-4B7B-8F98-B27815AE0390.png'
# Generating Code for '0517B767-FC77-46BC-A715-ACC170F416FA.png'
# Generating Code for '4F672D7E-C100-4734-A702-3A4FBE35C752.png'
# Generating Code for 'EBEC9F1E-90F1-4823-9893-F5E7D120A163.png'
# Generating Code for 'DCA1D7C3-E77D-4CA3-ABF6-057EEEA88C97.png'
# Generating Code for '9D34492A-8C6C-49BE-B90C-CBDD2B5B79F8.png'
# Generating Code for '5A314C3B-3650-411A-A17E-5969776A08B4.png'
# Generating Code for '66FDADD2-835C-4663-900F-75B8842E0EA6.png'
# Generating Code for 'B750743A-BAD7-483F-BB51-10131F1C4300.png'
# Generating Code for '8AB1859C-FE06-45A3-BBEF-BE7B8DF0021C.png'
# Generating Code for '03621937-2EB4-4EFB-9439-4F6FF664B849.png'
# Generating Code for 'BAD2406E-AEFB-40FB-A238-5F2764F28D9A.png'
# Generating Code for 'E9A829DF-328D-422B-9E5C-AF4E35865B28.png'
# Generating Code for 'E9F2F9E1-2161-4256-AB66-3895BB83A05E.png'
# Generating Code for '668E8674-EAAD-4F8A-BDC2-619DBB15DEFC.png'
# Generating Code for '3086CE0C-9C57-46D6-9E43-49EF4C3FDA03.png'
# Generating Code for '2339391E-0611-4722-8025-49C6F812CC04.png'
# Generating Code for '74E26FAA-6B21-4373-A7ED-5F40ED04EBD6.png'
# Generating Code for 'C0A97051-2A53-4506-A676-D673FA30800B.png'
# Generating Code for '0566F61B-9B69-4A36-B868-3BDB4FB19CB8.png'
# Generating Code for '86D636EE-7915-457A-92C1-EA9BA4D10309.png'
# Generating Code for '70AA7B4A-F9D8-4AF0-89EC-B75342AB26AC.png'
# Generating Code for 'AD18B166-AB5C-463B-BF01-8403C20756B1.png'
# Generating Code for 'EB142AF2-BA61-4B8F-A6A2-0160EF157B40.png'
# Generating Code for '356F9563-48D4-4A0C-98C9-154DD98F32F7.png'
# Generating Code for '3BC6C27E-A9C1-4040-963F-B863E99938B5.png'
# Generating Code for 'C7E63011-C0FA-4BD8-9051-A338C0E4BF8A.png'
# Generating Code for '4131F531-F8D6-4E96-92B2-7DDAB4636463.png'
# Generating Code for '7B6B57B2-C930-4734-9193-07AC712F1FBD.png'
# Generating Code for 'C0023C63-71DD-492A-AE66-34D495E65DB3.png'
# Generating Code for 'C58592BB-9A7B-4386-A459-5EC1E3F7667C.png'
# Generating Code for '67C7A591-4BB3-4A35-9493-F852B2AC3A6A.png'
# Generating Code for 'EC0646FC-B1B5-466A-9B52-988AF5B36936.png'
# Generating Code for '26225980-75AC-4544-AC6C-365F88092133.png'
# Generating Code for '9A5B520C-DB5E-4217-8C7B-D9272E0C5DD8.png'
# Generating Code for '85754F1B-72BF-440F-9875-88217A29E1A3.png'
# Generating Code for 'D08B5697-4881-4FA9-B1C3-E016A3C61CA7.png'
# Generating Code for '2CA52238-6B6E-4245-84DE-27C3913B1F6B.png'
# Generating Code for 'D622E22C-3484-4452-ABFE-C808044CFF0A.png'
# Generating Code for 'F2B267A0-36BA-49DF-83AE-3C735BBE7774.png'
# Generating Code for 'E0EC5CD5-84F6-4728-9A1D-67D86D2341D8.png'
# Generating Code for '0E04632D-5E83-450D-BDB0-92BB04CFAAD3.png'
# Generating Code for '99720969-917D-4843-BB69-D09AF953F258.png'
# Generating Code for 'CF987E30-DE3C-45B7-9FBD-F140E36E6B65.png'
# Generating Code for '9A6BAF80-60D4-4101-A0BB-875BEAAEE460.png'
# Generating Code for '284DBA08-8E68-427E-8BB1-70EA967692A7.png'
# Generating Code for '9FED117B-BEB3-4DED-876F-9280B776F8AA.png'
# Generating Code for '46CAEDEC-64C6-411C-A2F8-750C8E6BE90F.png'
# Generating Code for '3744C68A-634C-4A33-93A3-32DABDC2B8D7.png'
# Generating Code for '554868EF-3A24-466F-A63A-24D0E78F95ED.png'
# Generating Code for '3AD8509F-A870-4A05-BF80-909BED5EED6A.png'
# Generating Code for '01E3948F-2FD3-45E3-AB0A-0290BF5B7458.png'
# Generating Code for 'A4D96A4C-0A9B-450D-A9CC-2FE87470E5D6.png'
# Generating Code for '9765767C-8068-4B0B-94C5-6103F6743B76.png'
# Generating Code for '38637FF6-669F-4E0C-869B-D77D420B73F3.png'
# Generating Code for '495E5B30-ECD6-4C27-8FCA-638D90732D6B.png'
# Generating Code for 'BDADAED6-B1B1-4128-A51A-32963C5BA9A3.png'
# Generating Code for '99D2A686-197B-4780-BA24-F77230325BD1.png'
# Generating Code for 'FBF96431-3CFF-4168-BBBF-E0682A0728AB.png'
# Generating Code for '4E532EC8-4DF5-4731-9BE9-21ECF6FA171B.png'
# Generating Code for 'FAD962F2-28DC-4A70-9A78-2707C0A0FB12.png'
# Generating Code for 'F45E0C87-4022-4797-AC90-12EEA619D715.png'
# Generating Code for '9BDCA8BD-8505-4F33-93B9-A4B945666D73.png'
# Generating Code for '44AF62E7-895B-414E-9547-852EDD60F339.png'
# Generating Code for '39C19125-6A16-4E34-B592-F6C9FB367D06.png'
# Generating Code for '7322E82F-E47F-49D3-B5C7-E7E49D8EBD38.png'
# Generating Code for 'A7369735-4937-45EE-BE80-B3716622A6ED.png'
# Generating Code for '578BE21B-B784-42F9-9DC5-EAB79F31B53D.png'
# Generating Code for '3CDBAD4A-70C7-4840-8BAF-F7546FADB48C.png'
# Generating Code for '4DEEBE10-A29E-48C9-9CC6-EA6AA6AD4CA5.png'
# Generating Code for '9416A0F0-18CF-4688-8642-0458CF6229E8.png'
# Generating Code for '7152B7B4-2251-4ECF-8FF7-A689E98344BD.png'
# Generating Code for '7EEF813A-8FEB-489F-AEF6-2C72BC322092.png'
# Generating Code for '601173E2-D902-4478-968A-91DC5C59BED6.png'
# Generating Code for 'D01AF05D-3566-48F9-B95F-DF7A9040A398.png'
# Generating Code for '249E79C5-73A6-47D8-85BF-C6BBDC9F3C5D.png'
# Generating Code for '9380618D-25C7-4C72-8F6E-979765800BAE.png'
# Generating Code for 'DE0CA3C9-03DE-4BD7-AD3B-7A34517BAF30.png'
# Generating Code for 'A8A1127F-1CD3-41AE-9294-27405804AC3C.png'
# Generating Code for 'AA3D98BE-B01A-48D9-BFAD-03BEEEB7494A.png'
# Generating Code for '34AE3A08-0C51-4C1D-BC1F-4BDF6C5EBC04.png'
# Generating Code for 'C7BBB88F-07AA-4431-A747-394491FE8938.png'
# Generating Code for '2E51E977-0974-46A6-9A53-F38CF3187A23.png'
# Generating Code for '0E7804CD-B228-4B01-8C94-0B4F5D1A5B77.png'
# Generating Code for '639A412A-16AB-46D4-A91E-018018DA0049.png'
# Generating Code for 'F797E7A3-2E65-4753-8A95-2683C3C8DD61.png'
# Generating Code for 'CA6245B0-73AD-4A6C-A4C0-494DCD2095B5.png'
# Generating Code for '0143F087-C50D-4EE1-88AC-426056D71026.png'
# Generating Code for '2B4BE5AF-D965-4772-ABCB-33E37F233289.png'
# Generating Code for '3504EE39-D858-4E47-9BA8-6512082161D8.png'
# Generating Code for '14AA9C75-C03D-4CBA-85AE-1F278716809E.png'
# Generating Code for '3C405AA7-086D-41D0-A6CB-7154A386340C.png'
# Generating Code for '2518A8D9-7C2D-480A-8DB9-94440FA8D5E0.png'
# Generating Code for 'F144C4B3-7CFA-4326-8C7B-48F9BCB35DFF.png'
# Generating Code for '1C1C08C6-CF79-4351-A0C8-9E393643ADAB.png'
# Generating Code for '234CBBBB-4C28-4197-96E0-DBB5292665C1.png'
# Generating Code for '1A0B1DC8-8264-415D-B4FE-83D61C8EEB95.png'
# Generating Code for '00E15BB2-5568-4466-BA18-A8A8D34FC61C.png'
# Generating Code for 'DFD138B4-A4C3-4259-AC0F-B6F924FD94EC.png'
# Generating Code for '92FAC8AC-8203-4523-81B2-34BFC41A415B.png'
# Generating Code for '78C7A564-49F7-40A9-A20C-7414395BFB2C.png'
# Generating Code for '5AAA1791-7970-4EE0-891B-2898CBE15C51.png'
# Generating Code for '59B99BC1-A8BB-4D3B-B011-DDFFFF82B546.png'
# Generating Code for '53BEA532-62DA-40A0-B4E5-130ABCF11B18.png'
# Generating Code for 'F4F9BA11-C4DE-4E29-B006-EE52AFDC54C2.png'
# Generating Code for '649309DF-5F1C-4DCD-8826-D152401BE437.png'
# Generating Code for 'B1487066-824F-4ED5-A215-14F1C30F13BE.png'
# Generating Code for '165184D1-C09A-46E0-9D1B-E020862683C1.png'
# Generating Code for '05603517-666B-44EC-86D1-DFB14F81C639.png'
# Generating Code for 'CC093E3F-C88F-4AB6-808B-D0BFEE4CDAA1.png'
# Generating Code for '7EAF74DE-03CA-4BD3-A704-F06D824D8B9F.png'
# Generating Code for '988C829D-D37A-4A47-A5A6-D476F2FF8656.png'
# Generating Code for '95BDA601-26DE-4B95-A37C-36791342C64E.png'
# Generating Code for 'B0F121B5-B1A4-45DE-A8A8-316319BB0543.png'
# Generating Code for '89BC0E37-A644-4960-9791-9B3913A9938B.png'
# Generating Code for '3AE9F8AB-D477-4F61-9216-32D0244F3965.png'
# Generating Code for '7309EA09-0EE2-4EA3-A710-1E6025B93BA3.png'
# Generating Code for '30F7DCCF-EFC4-421F-B0DE-046C19948DBA.png'
# Generating Code for '87777D85-3598-47C2-ABF8-3DFB8DD5010A.png'
# Generating Code for '89E24C7D-C098-4B37-B164-CD30A6B9377C.png'
# Generating Code for 'CD8E2464-1842-42CA-B37B-B9333DAA7CD1.png'
# Generating Code for '958B0823-9272-441D-94CA-043F29C31A40.png'
# Generating Code for 'ADE9B442-C9D4-4583-BF96-374D792ACF19.png'
# Generating Code for '2EA0DFF5-8FD4-4C72-B671-8DCF201B95F5.png'
# Generating Code for '4D088ED4-0519-48B5-AE42-C26110FA719C.png'
# Generating Code for '3385E80A-66EF-4BA9-98D0-F3BECAFCE786.png'
# Generating Code for 'A6FE1CF4-0A2B-4F46-B7B7-B2DF00B73156.png'
# Generating Code for 'D2FB17E7-7C5C-45BB-8EB0-2D8714D01954.png'
# Generating Code for 'DA6EA8A3-A744-4D04-AD80-3A405B73A7D1.png'
# Generating Code for 'B353B1D9-302A-46A6-A4EB-06809BC30E29.png'
# Generating Code for 'E84BE5A0-EE0D-46EC-9928-DE2E42466B4E.png'
# Generating Code for '65381B1C-1E6E-4F89-84F4-9A082790FDE9.png'
# Generating Code for '1D11B6D4-9295-4691-8025-FADE944F401E.png'
# Generating Code for '5327289B-547C-4012-8C5B-FDD8ECDE3679.png'
# Generating Code for '461B4E2F-0FF5-4823-B26B-B2B549E4C572.png'
# Generating Code for '41E3B8F7-C3E0-48F2-B0B9-509EC5A9AD1B.png'
# Generating Code for '75E3BCB3-BA79-43E0-A4B0-E1BE6A8DD18B.png'
# Generating Code for 'B611CCD1-7A02-45EC-A4AF-EB9BAF1451A0.png'
# Generating Code for 'A8D12708-56B9-4F32-B4CC-07F59B58E62B.png'
# Generating Code for '5D5EBB70-F1B8-40D6-B76E-C2008F210C99.png'
# Generating Code for '3CC3E0EC-8AE1-4673-914C-65C439C448F8.png'
# Generating Code for '84A9D352-DC8B-4FA9-BF8F-E9C445F5928C.png'
# Generating Code for 'A6CC2F02-4F12-4F4D-9550-AFD5BA936B1B.png'
# Generating Code for 'B2EC8B50-C6A4-4898-A46B-C7BC46E1B2CC.png'
# Generating Code for '4672FFD0-D56E-4851-A669-732282540A08.png'
# Generating Code for 'BAF5928D-521B-4ACA-95BE-F24B8385BB23.png'
# Generating Code for '21F78C52-1740-4B17-ADAA-00564D243DD9.png'
# Generating Code for 'F34B663D-DDE1-43A2-9DF5-F57C0CEC357C.png'
# Generating Code for '2F3F9469-1669-4469-8FE1-21A2492E0570.png'
# Generating Code for '0760CA6A-B885-455B-AE48-DD9F8AF4C334.png'
# Generating Code for '722E3BB5-E721-455D-AFD6-61CEC4273C19.png'
# Generating Code for '423EE3F0-871A-4436-8C2C-BD6434C8AA64.png'
# Generating Code for 'D6295385-D729-4FC5-AE5A-53EC78E69C22.png'
# Generating Code for '21922B7B-A1E5-442E-BB3A-BE607A5F9345.png'
# Generating Code for '4F94AB9E-CD20-4629-94F5-3D009B3A0376.png'
# Generating Code for '57C11935-8B39-46FF-88D2-0D3FA695B2B7.png'
# Generating Code for 'B5D9F004-CF08-40C5-B009-9DAC5EC1BB9C.png'
# Generating Code for 'E59DED37-C192-4976-A99D-2DBF663215F7.png'
# Generating Code for '3D3C6079-7F28-4527-8AD9-9E8EDD2CB862.png'
# Generating Code for '31A4467A-9C93-4D87-81F9-BB09FC7D67A2.png'
# Generating Code for '6549906D-62D4-4917-A286-D6A3276CC490.png'
# Generating Code for '3394E4B6-6ED9-4A65-AB9A-60CF92D173B9.png'
# Generating Code for '58CA413A-12D1-4B16-B7C8-9A22D0BCDFD5.png'
# Generating Code for '793F2749-9E00-41D7-8193-86778FBB8629.png'
# Generating Code for '10CD315C-7EDA-4D5C-AEB6-0AE9C0E98F93.png'
# Generating Code for '827E8BFD-FDBD-4540-8512-7366122E45A0.png'
# Generating Code for 'FDC5BDA9-5E86-4020-82E7-2F231E0B890A.png'
# Generating Code for '2C9CB527-F490-4318-9EF0-4D3DB32FBA16.png'
# Generating Code for '4F1BF1A9-DE6B-4935-87BE-9BA67FE68773.png'
# Generating Code for '590B3809-2FB1-4EB6-AC21-E7EF83163762.png'
# Generating Code for 'A933808A-F713-4639-B599-C8E17A6510F1.png'
# Generating Code for '17441C16-6671-4478-B793-671F3926BE69.png'
# Generating Code for 'CB5A78AB-FC11-45F6-A6E7-06FAEF7A8EA6.png'
# Generating Code for '4414C575-EF1C-4F9F-8645-3213EA59F4AC.png'
# Generating Code for 'D8FCA0C7-E94F-4530-8D90-E2DFE221617E.png'
# Generating Code for 'F24D931A-4A53-45D2-83DF-E30397096C0E.png'
# Generating Code for 'BA6BE317-E026-475F-BEAD-0A8BD2DB4D24.png'
# Generating Code for 'CFA77089-89FB-4CE3-B984-07E36810126A.png'
# Generating Code for '623BADB7-0078-4374-9FE8-DC98FE95B78B.png'
# Generating Code for '57D2D9AB-BF07-4E20-8AE6-304262A87304.png'
# Generating Code for 'CE7442AA-AF3A-4390-B269-37885A24BDB3.png'
# Generating Code for 'B35A8109-822D-4326-9A52-6694A9D733A5.png'
# Generating Code for '109ED3A8-BCBB-460A-BE0D-90B160E7CC47.png'
# Generating Code for 'A204C983-9CCB-47D8-AFDE-673F831281AA.png'
# Generating Code for '4BA0F041-9533-4A5F-974A-AD2E3AFE491D.png'
# Generating Code for '2154AB0E-54CA-484D-AAC5-F3984980EA6A.png'
# Generating Code for '569D0502-7315-47E0-AB27-D9BB3EB82D9D.png'
# Generating Code for '6582E0A6-5240-43B5-A4CD-0B5E1F740A82.png'
# Generating Code for '8DCB8335-C63D-4582-91AD-47C94AF65EE2.png'
# Generating Code for 'E3131E30-C9B4-447E-8E5B-C2E599635B92.png'
# Generating Code for '16E05E7C-10D2-4A4B-8186-48A1334494CF.png'
# Generating Code for 'DB3C4CE6-4C28-42DD-BF1D-15EA3A32F022.png'
# Generating Code for 'DA8F2A8D-70C4-4BCD-8C4F-460C6FC2A1C7.png'
# Generating Code for '06FEF995-3AC3-4ECC-8143-53A3167EB2B5.png'
# Generating Code for '30C284F0-37B6-4D1F-B6E1-807BD37137B7.png'
# Generating Code for 'FDF4126C-C97E-43F0-9624-2AFC2D6BAD69.png'
# Generating Code for '76B5F111-DD0B-4BA8-8C72-76B4E641466B.png'
# Generating Code for '93010B40-2034-40B7-8543-228964153459.png'
# Generating Code for '036C9412-D477-46B7-9F7F-6B4A3B5B1F50.png'
# Generating Code for 'D670AD8D-DD4D-4C72-9E75-8DA532391FA7.png'
# Generating Code for '8B03AC02-A718-4316-9A79-9DBE014789EC.png'
# Generating Code for '2D2D892B-1D0C-4B69-90CA-4C3F2BD20301.png'
# Generating Code for '5CD905AB-F521-4284-9E3F-5AA8B29CE258.png'
# Generating Code for '59D995EE-416B-4F64-97DD-157E1C82AAB3.png'
# Generating Code for '33946EDA-14FD-4310-BF01-C064E63E88B5.png'
# Generating Code for 'D50B9FB8-1FFA-4602-90E3-EFAFF99BF315.png'
# Generating Code for 'F503751C-80B0-4AB1-BEDB-CA168DC931F7.png'
# Generating Code for '0C8D1647-C0B7-43A3-AB68-AB4F8D7DC234.png'
# Generating Code for 'A61B6DE5-E2C9-4E05-9A24-CF2B4D19DD5B.png'
# Generating Code for '94717179-6D5E-49B7-8F6C-E266C65AF9F3.png'
# Generating Code for '9B0DC18C-A468-42BC-B112-D4ED55D9D711.png'
# Generating Code for '41DDFA16-DF58-47D1-86FB-6A9903D3E239.png'
# Generating Code for '9B7FA9BC-2B10-48DF-B181-43C6EE268A96.png'
# Generating Code for '798794D9-56F9-4C2F-BD49-223FDC6CE76A.png'
# Generating Code for '9B2F4DC6-105A-43EE-87D5-63DBB44F3F20.png'
# Generating Code for '297CC274-9687-4D91-80C2-C7D827903FBD.png'
# Generating Code for '7E2908B5-A669-4956-926F-A41DE7DA839E.png'
# Generating Code for '1A842D49-87FC-494B-AA85-929C5F709CE8.png'
# Generating Code for 'BEE54C73-5B59-449A-A0C3-52C426522DC1.png'
# Generating Code for '72D91FC8-630B-4312-B35B-03866F094C61.png'
# Generating Code for 'E217333F-87E3-4671-8F4E-05B4DC66EA0D.png'
# Generating Code for 'DE77DB11-79E0-4D41-B15A-2ACAD1A3E42D.png'
# Generating Code for '75CDF874-429A-44DD-9CBB-49C35B830944.png'
# Generating Code for '43DDF132-B905-4A4C-B577-0E77A654F2AF.png'
# Generating Code for '5F71CD2D-049A-4F12-AA0D-BD3910D4B898.png'
# Generating Code for '360904AB-E2FD-45A6-8F11-F23EFDF45E49.png'
# Generating Code for '4980F137-1FAE-438A-9E24-0A0652434D97.png'
# Generating Code for '45DA9E46-6E8B-4E9B-A2CB-10F884FE61FA.png'
# Generating Code for '3FC791D7-85F5-439B-AD8E-BE170AD4B5B6.png'
# Generating Code for '1D3BE75B-3F8F-4004-A562-2B784AF8D1EC.png'
# Generating Code for 'DD06DE8C-3A72-4DDD-9F57-96B3F62811AB.png'
# Generating Code for '126F52F9-D9E8-43C4-9AAC-CC3A8BA6BCF7.png'
# Generating Code for 'C8F69595-5EFB-43DF-BF1E-629C1C3BE109.png'
# Generating Code for 'BB0919BA-CF1A-4178-8D48-E95997610117.png'
# Generating Code for '298A4374-AC0C-4366-BABF-94A22369AF5F.png'
# Generating Code for '46308B29-D145-4269-8002-9A7AC486333C.png'
# Generating Code for '1B780AA6-20D0-481F-976F-C951B0D0F57E.png'
# Generating Code for '4A248DA1-2228-4972-AB16-883BBA7C75DB.png'
# Generating Code for '3D99910F-C6A3-4FF6-985D-F71AC4652DA7.png'
# Generating Code for 'A98BB4F5-3DE7-4754-9B02-B95ACD297F01.png'
# Generating Code for '922B7A61-8FE9-42ED-BB94-7B6D46AB3F91.png'
# Generating Code for '1DA89743-53E9-45B0-BB0D-03EB95AA4879.png'
# Generating Code for 'F991FF54-0127-417A-96A9-2D15C2D70C77.png'
# Generating Code for '81559FDB-1B9A-4D4E-9E91-7045A19BA4EE.png'
# Generating Code for '1EB42A93-71AB-4631-AF7A-42B9CB2BC52A.png'
# Generating Code for '88E1A5E7-7AE4-4DEF-8687-CB5426CA9FBA.png'
# Generating Code for '4E78230B-9C23-4824-9DAC-15EF9B72E717.png'
# Generating Code for 'CF4AAA07-BACB-49B6-9C12-A003355377B7.png'
# Generating Code for '8304A59C-7382-4F02-BBF2-1B07911C687B.png'
# Generating Code for '942C131E-C3EF-488E-A8BC-C482F647C38A.png'
# Generating Code for 'F2E9F75E-CE47-405C-8013-B792FF176EA1.png'
# Generating Code for '70324C0D-F525-4D3A-89A1-A660F32BF762.png'
# Generating Code for '20A1A20E-53F2-44D1-94F9-BD1ADC33C0F2.png'
# Generating Code for '63954D63-A8E1-48BE-83D2-2EA8180AB7F1.png'
# Generating Code for '31B7A383-F196-40B5-B932-9BA6D7E4C37A.png'
# Generating Code for '44DD70B7-D8AB-4650-947E-1C413A8608BA.png'
# Generating Code for '392A74C3-1B51-4AD6-9EF0-B2328EB21ADA.png'
# Generating Code for '23F6AE96-E095-4FF4-868B-5AC7F72C44E4.png'
# Generating Code for '22E99DEB-D65C-4383-BCD6-D4B2A33C409D.png'
# Generating Code for '7D25762F-3AE5-4B7C-8DC3-3BB019FA7DA1.png'
# Generating Code for '32F145B1-6850-4EFF-8A50-DBF34EFCFF78.png'
# Generating Code for '3250867F-52FA-4BFE-BA3B-9DA28D313CDC.png'
# Generating Code for '71834BFC-62FD-4601-BB36-1C7B80F31832.png'
# Generating Code for '6FEC2BEC-CD9F-4363-AA9D-60A791C8DD92.png'
# Generating Code for 'C74CD078-EBE7-4741-BDBD-BF1D9E6C51CF.png'
# Generating Code for 'CF53AD29-3BF0-4B9E-A110-C9392BBF9BA4.png'
# Generating Code for '16842254-E7C5-45A5-895F-BFF5E10FB478.png'
# Generating Code for '533A7F8F-D883-4D6C-A0BC-91AA7FA90E8F.png'
# Generating Code for '0877A39E-7D17-4C49-85E4-32FA784AB116.png'
# Generating Code for 'A4090258-5013-4A7E-873C-F59E513E3E54.png'
# Generating Code for 'A83634E6-0C82-4A90-8A27-83CD433D9EE4.png'
# Generating Code for 'B472A080-7907-4EA3-97D0-074CD215CFF3.png'
# Generating Code for '8D586BF3-661F-4136-BB07-729E56DF6468.png'
# Generating Code for '185155FE-31A6-4162-98FA-3DBB9D243819.png'
# Generating Code for '0E2107B9-3F77-4D5E-9FC0-29B40CA9B7F0.png'
# Generating Code for 'B7049850-C831-4995-91DA-77F6E40C4057.png'
# Generating Code for 'E1637792-9F70-41BC-844C-D6A9954ED63B.png'
# Generating Code for '1F4F53E3-ED8C-40C8-9330-5793DF8D86F4.png'
# Generating Code for '3B660928-2B27-477B-ACEF-090DA6BF76B4.png'
# Generating Code for '2B646D9C-F209-4ED7-A26E-CE2532110AA9.png'
# Generating Code for 'D68EAA47-D031-42D4-876A-370EAA5DE925.png'
# Generating Code for '469C4AD7-A487-4320-BCFA-1C22BAF3C47B.png'
# Generating Code for '453FB0F6-CFD2-40AE-805E-C723F05516E3.png'
# Generating Code for '4367D6D6-6C72-4CE2-A4FE-52F37CB331F7.png'
# Generating Code for '88D1C46D-B5AB-4738-8FBC-18272D3870D2.png'
# Generating Code for '6859E3C7-BB31-4297-8945-0FDF776FAAFF.png'
# Generating Code for '4A0C7594-FFB9-4110-917A-406764BE516E.png'
# Generating Code for '52437DB9-FC03-4DA1-A827-1A449D16CF70.png'
# Generating Code for '02AC4408-AC50-4ADE-9AB0-10479A69987F.png'
# Generating Code for '4D9CE5F9-B9CD-4268-829E-81DF7B9D332F.png'
# Generating Code for 'C331289C-1E8D-42DD-855C-752C12FB9C7B.png'
# Generating Code for '17019253-EEBB-4D17-BAE0-12D91F9764ED.png'
# Generating Code for 'C20ED7B2-C1A0-49BF-A785-74ECCA69D554.png'
# Generating Code for '3B0EB092-42B8-4F3F-A8FF-551C3893A2D3.png'
# Generating Code for '8D0E9D81-D7FA-447F-8AEB-E38B1330E2B9.png'
# Generating Code for '01B6145F-B88B-4FF8-B7D7-BB8A321EDA85.png'
# Generating Code for 'DDBC561D-5F65-4D2C-A6CC-3CC7DF54097F.png'
# Generating Code for '2FE0458E-E77E-4D64-A894-BAFA401ADC26.png'
# Generating Code for '6FFA4280-09CD-4008-89F4-C456CD76763C.png'
# Generating Code for 'E42BA116-F896-4D64-AE68-09DD54F91D12.png'
# Generating Code for '92152E13-0F49-4377-85D1-B41B6828129A.png'
# Generating Code for '138C462D-CB33-42EA-B824-3EFC85D813E0.png'
# Generating Code for '2C3FE2D6-941B-4488-A22E-C6B3A80D9668.png'
# Generating Code for '21C114BE-1A48-423D-863C-155F1A847673.png'
# Generating Code for '07E7C220-9A9D-4A03-A355-7F7518DF1C7D.png'
# Generating Code for 'A1346F7D-86D9-4DAA-94AF-9878B980C4C2.png'
# Generating Code for 'BAC084FF-7F80-40C8-BA01-1F501473A982.png'
# Generating Code for '41C19FBD-6990-48DA-A33B-C30E500AA1E0.png'
# Generating Code for '1C6A3208-B2C1-4D10-9EF9-5D954C87EB35.png'
# Generating Code for '3214A0CD-C260-467D-9188-CF0B7233AFD2.png'
# Generating Code for '35D4728C-C9A6-4EF3-9138-E7538375F201.png'
# Generating Code for '9D8069D1-C0BA-428B-8454-7CDBA626659B.png'
# Generating Code for '837749D1-9C4D-46C5-8C49-600EEE296577.png'
# Generating Code for 'BB09B92A-8042-4CA9-A5BB-6F37499876BF.png'
# Generating Code for 'ED53717E-A152-4D17-89C6-B4C2999CD915.png'
# Generating Code for '30B8C9C1-9D71-4187-9EE5-793963673387.png'
# Generating Code for 'A9FC1D77-819D-411C-AC1D-E84DEE824F50.png'
# Generating Code for 'C2C339E9-37F0-481E-A8B9-CBC714746A18.png'
# Generating Code for '5DDE4ADE-0C77-4D1F-98D4-14109FE47C1A.png'
# Generating Code for 'EB8A035F-21D7-44B4-A2A7-27C18C0110B1.png'
# Generating Code for '631A35C2-6608-4F70-87E5-49481BBADC42.png'
# Generating Code for '38C2DC07-B2F6-4840-887C-87A5E1DC0FE5.png'
# Generating Code for 'EA7488EC-E228-4630-9ACE-5875C4A1CC18.png'
# Generating Code for '3C583DE4-E7AE-4814-A668-84AC9D752074.png'
# Generating Code for '50C81911-47A8-4A74-9E88-EC9288A10B62.png'
# Generating Code for '6565083F-5250-413D-9103-FE13C4D8B3A2.png'
# Generating Code for '69B79156-171A-45F1-8366-D5E611120C83.png'
# Generating Code for '8E1D77C9-8476-48C1-A29B-1BA833D536CA.png'
# Generating Code for '1A34189E-6A1A-40E1-A2F0-A8BC0A34A5D2.png'
# Generating Code for 'E58495AD-AEE4-4CC7-B755-0E2FA3A79EB4.png'
# Generating Code for '6DE60296-8EF2-4115-B37D-928FC0839161.png'
# Generating Code for 'A662BCE1-F1CD-4CE3-A4E7-64F8DE95FAF6.png'
# Generating Code for '1918E602-6EAF-4471-AFB9-4C648A35A952.png'
# Generating Code for 'F8755290-18E6-417D-AB35-5D103B58934E.png'
# Generating Code for '2BE88645-6FCA-4DF2-B1CA-BB6A1097135C.png'
# Generating Code for '921FFFE6-DF54-4FD7-884D-A10BB96F93B4.png'
# Generating Code for 'FB58284C-D093-4A48-9E4F-D9E74C206042.png'
# Generating Code for 'B0479D48-9E77-4CC2-95AB-BFAE9E666019.png'
# Generating Code for '355278CC-B263-4A1B-913B-9C2331988EEE.png'
